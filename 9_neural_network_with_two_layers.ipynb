# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
# A function to create a dataset.
from sklearn.datasets import make_blobs

# Output of plotting commands is displayed inline within the Jupyter notebook.
# %matplotlib inline 

# Set a seed so that the results are consistent.
np.random.seed(3)

# %%
fig, ax = plt.subplots()
xmin, xmax = -0.2, 1.4
x_line = np.arange(xmin, xmax, 0.1)
# Data points (observations) from two classes.
ax.scatter(0, 0, color="r")
ax.scatter(0, 1, color="b")
ax.scatter(1, 0, color="b")
ax.scatter(1, 1, color="r")
ax.set_xlim([xmin, xmax])
ax.set_ylim([-0.1, 1.1])
ax.set_xlabel("$x_1$")
ax.set_ylabel("$x_2$")
# Example of the lines which can be used as a decision boundary to separate two classes.
ax.plot(x_line, -1 * x_line + 1.5, color="black")
ax.plot(x_line, -1 * x_line + 0.5, color="black")
plt.plot()
# Out:
# []

# %%
m = 2000
samples, labels = make_blobs(
    n_samples=m,
    centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]),
    cluster_std=1.1,
    random_state=0,
)
labels[(labels == 0) | (labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 0
X = np.transpose(samples)
Y = labels.reshape((1, m))

plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(["blue", "red"]))

print("The shape of X is: " + str(X.shape))
print("The shape of Y is: " + str(Y.shape))
print("I have m = %d training examples!" % (m))
# Out:
# The shape of X is: (2, 2000)
# The shape of Y is: (1, 2000)
# I have m = 2000 training examples!

# %%
def sigmoid(z):
    res = 1 / (1 + np.exp(-1 * z))

    return res

# %%
print("sigmoid(-2) = " + str(sigmoid(-2)))
print("sigmoid(0) = " + str(sigmoid(0)))
print("sigmoid(3.5) = " + str(sigmoid(3.5)))
# Out:
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436

# %%
def layer_sizes(X, Y):
    """
    Arguments:
    X -- input dataset of shape (input size, number of examples)
    Y -- labels of shape (output size, number of examples)

    Returns:
    n_x -- the size of the input layer
    n_h -- the size of the hidden layer
    n_y -- the size of the output layer
    """
    # Size of input layer.
    n_x = X.shape[0]
    # Size of hidden layer.
    n_h = 2
    # Size of output layer.
    n_y = Y.shape[0]
    return (n_x, n_h, n_y)

# %%
(n_x, n_h, n_y) = layer_sizes(X, Y)
print("The size of the input layer is: n_x = " + str(n_x))
print("The size of the hidden layer is: n_h = " + str(n_h))
print("The size of the output layer is: n_y = " + str(n_y))
# Out:
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1

# %%
# GRADED FUNCTION: initialize_parameters


def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer

    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """

    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.zeros((n_h, 1))
    W2 = np.random.randn(n_y, n_h) * 0.01
    b2 = np.zeros((n_y, 1))

    assert W1.shape == (n_h, n_x)
    assert b1.shape == (n_h, 1)
    assert W2.shape == (n_y, n_h)
    assert b2.shape == (n_y, 1)

    parameters = {"W1": W1, "b1": b1, "W2": W2, "b2": b2}

    return parameters

# %%
parameters = initialize_parameters(n_x, n_h, n_y)

print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]

# %%
def forward_propagation(X, parameters):
    """
    Argument:
    X -- input data of size (n_x, m)
    parameters -- python dictionary containing your parameters (output of initialization function)

    Returns:
    A2 -- the sigmoid output of the second activation
    cache -- python dictionary containing Z1, A1, Z2, A2
    (that simplifies the calculations in the back propagation step)
    """
    # Retrieve each parameter from the dictionary "parameters".
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]

    # Implement forward propagation to calculate A2.
    Z1 = np.matmul(W1, X) + b1
    A1 = sigmoid(Z1)
    Z2 = np.matmul(W2, A1) + b2
    A2 = sigmoid(Z2)

    assert A2.shape == (n_y, X.shape[1])

    cache = {"Z1": Z1, "A1": A1, "Z2": Z2, "A2": A2}

    return A2, cache

# %%
A2, cache = forward_propagation(X, parameters)

print(A2)
# Out:
# [[0.49920157 0.49922234 0.49921223 ... 0.49921215 0.49921043 0.49920665]]

# %%
def compute_cost(A2, Y):
    """
    Computes the cost function as a log loss

    Arguments:
    A2 -- The output of the neural network of shape (1, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)

    Returns:
    cost -- log loss

    """
    # Number of examples.
    m = Y.shape[1]

    logloss = -1 * Y * np.log(A2) - (1 - Y) * np.log(1 - A2)
    cost = np.sum(logloss) / m

    assert isinstance(cost, float)

    return cost

# %%
print("cost = " + str(compute_cost(A2, Y)))
# Out:
# cost = 0.6931477703826822

# %%
def backward_propagation(parameters, cache, X, Y):
    """
    Implements the backward propagation, calculating gradients

    Arguments:
    parameters -- python dictionary containing our parameters
    cache -- python dictionary containing Z1, A1, Z2, A2
    X -- input data of shape (n_x, number of examples)
    Y -- "true" labels vector of shape (n_y, number of examples)

    Returns:
    grads -- python dictionary containing gradients with respect to different parameters
    """
    m = X.shape[1]

    # First, retrieve W from the dictionary "parameters".
    W1 = parameters["W1"]
    W2 = parameters["W2"]

    # Retrieve also A1 and A2 from dictionary "cache".
    A1 = cache["A1"]
    A2 = cache["A2"]

    # Backward propagation: calculate partial derivatives denoted as dW1, db1, dW2, db2 for simplicity.
    dZ2 = A2 - Y
    dW2 = 1 / m * np.dot(dZ2, A1.T)
    db2 = 1 / m * np.sum(dZ2, axis=1, keepdims=True)
    dZ1 = np.dot(W2.T, dZ2) * A1 * (1 - A1)
    dW1 = 1 / m * np.dot(dZ1, X.T)
    db1 = 1 / m * np.sum(dZ1, axis=1, keepdims=True)

    grads = {"dW1": dW1, "db1": db1, "dW2": dW2, "db2": db2}

    return grads


grads = backward_propagation(parameters, cache, X, Y)

print("dW1 = " + str(grads["dW1"]))
print("db1 = " + str(grads["db1"]))
print("dW2 = " + str(grads["dW2"]))
print("db2 = " + str(grads["db2"]))
# Out:
# dW1 = [[-1.49856632e-05  1.67791519e-05]
#  [-2.12394543e-05  2.43895135e-05]]
# db1 = [[5.11207671e-07]
#  [7.06236219e-07]]
# dW2 = [[-0.00032641 -0.0002606 ]]
# db2 = [[-0.00078732]]

# %%
def update_parameters(parameters, grads, learning_rate=1.2):
    """
    Updates parameters using the gradient descent update rule

    Arguments:
    parameters -- python dictionary containing parameters
    grads -- python dictionary containing gradients
    learning_rate -- learning rate for gradient descent

    Returns:
    parameters -- python dictionary containing updated parameters
    """
    # Retrieve each parameter from the dictionary "parameters".
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]

    # Retrieve each gradient from the dictionary "grads".
    dW1 = grads["dW1"]
    db1 = grads["db1"]
    dW2 = grads["dW2"]
    db2 = grads["db2"]

    # Update rule for each parameter.
    W1 = W1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    W2 = W2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2

    parameters = {"W1": W1, "b1": b1, "W2": W2, "b2": b2}

    return parameters

# %%
parameters_updated = update_parameters(parameters, grads)

print("W1 updated = " + str(parameters_updated["W1"]))
print("b1 updated = " + str(parameters_updated["b1"]))
print("W2 updated = " + str(parameters_updated["W2"]))
print("b2 updated = " + str(parameters_updated["b2"]))
# Out:
# W1 updated = [[ 0.01790427  0.00434496]
#  [ 0.00099046 -0.01866419]]
# b1 updated = [[-6.13449205e-07]
#  [-8.47483463e-07]]
# W2 updated = [[-0.00238219 -0.00323487]]
# b2 updated = [[0.00094478]]

# %%
def nn_model(X, Y, n_h, num_iterations=10, learning_rate=1.2, print_cost=False):
    """
    Arguments:
    X -- dataset of shape (n_x, number of examples)
    Y -- labels of shape (n_y, number of examples)
    num_iterations -- number of iterations in the loop
    learning_rate -- learning rate parameter for gradient descent
    print_cost -- if True, print the cost every iteration

    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """

    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]

    # Initialize parameters.
    parameters = initialize_parameters(n_x, n_h, n_y)

    # Loop.
    for i in range(0, num_iterations):
        # Forward propagation. Inputs: "X, parameters". Outputs: "A2, cache".
        A2, cache = forward_propagation(X, parameters)

        # Cost function. Inputs: "A2, Y". Outputs: "cost".
        cost = compute_cost(A2, Y)

        # Backpropagation. Inputs: "parameters, cache, X, Y". Outputs: "grads".
        grads = backward_propagation(parameters, cache, X, Y)

        # Gradient descent parameter update. Inputs: "parameters, grads, learning_rate". Outputs: "parameters".
        parameters = update_parameters(parameters, grads, learning_rate)

        # Print the cost every iteration.
        if print_cost:
            print("Cost after iteration %i: %f" % (i, cost))

    return parameters

# %%
parameters = nn_model(
    X, Y, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=True
)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))

W1 = parameters["W1"]
b1 = parameters["b1"]
W2 = parameters["W2"]
b2 = parameters["b2"]
# Out:
# Cost after iteration 0: 0.693179
# Cost after iteration 1: 0.693157
# Cost after iteration 2: 0.693150
# Cost after iteration 3: 0.693148
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# Cost after iteration 6: 0.693147
# Cost after iteration 7: 0.693147
# Cost after iteration 8: 0.693147
# Cost after iteration 9: 0.693147
# Cost after iteration 10: 0.693147
# Cost after iteration 11: 0.693147
# Cost after iteration 12: 0.693147
# Cost after iteration 13: 0.693147
# Cost after iteration 14: 0.693147
# Cost after iteration 15: 0.693147
# Cost after iteration 16: 0.693147
# Cost after iteration 17: 0.693147
# Cost after iteration 18: 0.693147
# Cost after iteration 19: 0.693147
# Cost after iteration 20: 0.693147
# Cost after iteration 21: 0.693147
# Cost after iteration 22: 0.693147
# Cost after iteration 23: 0.693147
# Cost after iteration 24: 0.693147
# Cost after iteration 25: 0.693147
# Cost after iteration 26: 0.693147
# Cost after iteration 27: 0.693147
# Cost after iteration 28: 0.693146
# Cost after iteration 29: 0.693146
# Cost after iteration 30: 0.693146
# Cost after iteration 31: 0.693146
# Cost after iteration 32: 0.693146
# Cost after iteration 33: 0.693146
# Cost after iteration 34: 0.693146
# Cost after iteration 35: 0.693146
# Cost after iteration 36: 0.693146
# Cost after iteration 37: 0.693146
# Cost after iteration 38: 0.693146
# Cost after iteration 39: 0.693146
# Cost after iteration 40: 0.693146
# Cost after iteration 41: 0.693146
# Cost after iteration 42: 0.693146
# Cost after iteration 43: 0.693146
# Cost after iteration 44: 0.693146
# Cost after iteration 45: 0.693146
# Cost after iteration 46: 0.693146
# Cost after iteration 47: 0.693146
# Cost after iteration 48: 0.693146
# Cost after iteration 49: 0.693146
# Cost after iteration 50: 0.693146
# Cost after iteration 51: 0.693146
# Cost after iteration 52: 0.693146
# Cost after iteration 53: 0.693146
# Cost after iteration 54: 0.693145
# Cost after iteration 55: 0.693145
# Cost after iteration 56: 0.693145
# Cost after iteration 57: 0.693145
# Cost after iteration 58: 0.693145
# Cost after iteration 59: 0.693145
# Cost after iteration 60: 0.693145
# Cost after iteration 61: 0.693145
# Cost after iteration 62: 0.693145
# Cost after iteration 63: 0.693145
# Cost after iteration 64: 0.693145
# Cost after iteration 65: 0.693145
# Cost after iteration 66: 0.693145
# Cost after iteration 67: 0.693145
# Cost after iteration 68: 0.693145
# Cost after iteration 69: 0.693145
# Cost after iteration 70: 0.693145
# Cost after iteration 71: 0.693145
# Cost after iteration 72: 0.693145
# Cost after iteration 73: 0.693145
# Cost after iteration 74: 0.693144
# Cost after iteration 75: 0.693144
# Cost after iteration 76: 0.693144
# Cost after iteration 77: 0.693144
# Cost after iteration 78: 0.693144
# Cost after iteration 79: 0.693144
# Cost after iteration 80: 0.693144
# Cost after iteration 81: 0.693144
# Cost after iteration 82: 0.693144
# Cost after iteration 83: 0.693144
# Cost after iteration 84: 0.693144
# Cost after iteration 85: 0.693144
# Cost after iteration 86: 0.693144
# Cost after iteration 87: 0.693144
# Cost after iteration 88: 0.693144
# Cost after iteration 89: 0.693143
# Cost after iteration 90: 0.693143
# Cost after iteration 91: 0.693143
# Cost after iteration 92: 0.693143
# Cost after iteration 93: 0.693143
# Cost after iteration 94: 0.693143
# Cost after iteration 95: 0.693143
# Cost after iteration 96: 0.693143
# Cost after iteration 97: 0.693143
# Cost after iteration 98: 0.693143
# Cost after iteration 99: 0.693143
# Cost after iteration 100: 0.693142
# Cost after iteration 101: 0.693142
# Cost after iteration 102: 0.693142
# Cost after iteration 103: 0.693142
# Cost after iteration 104: 0.693142
# Cost after iteration 105: 0.693142
# Cost after iteration 106: 0.693142
# Cost after iteration 107: 0.693142
# Cost after iteration 108: 0.693142
# Cost after iteration 109: 0.693142
# Cost after iteration 110: 0.693141
# Cost after iteration 111: 0.693141
# Cost after iteration 112: 0.693141
# Cost after iteration 113: 0.693141
# Cost after iteration 114: 0.693141
# Cost after iteration 115: 0.693141
# Cost after iteration 116: 0.693141
# Cost after iteration 117: 0.693141
# Cost after iteration 118: 0.693140
# Cost after iteration 119: 0.693140
# Cost after iteration 120: 0.693140
# Cost after iteration 121: 0.693140
# Cost after iteration 122: 0.693140
# Cost after iteration 123: 0.693140
# Cost after iteration 124: 0.693140
# Cost after iteration 125: 0.693139
# Cost after iteration 126: 0.693139
# Cost after iteration 127: 0.693139
# Cost after iteration 128: 0.693139
# Cost after iteration 129: 0.693139
# Cost after iteration 130: 0.693139
# Cost after iteration 131: 0.693138
# Cost after iteration 132: 0.693138
# Cost after iteration 133: 0.693138
# Cost after iteration 134: 0.693138
# Cost after iteration 135: 0.693138
# Cost after iteration 136: 0.693138
# Cost after iteration 137: 0.693137
# Cost after iteration 138: 0.693137
# Cost after iteration 139: 0.693137
# Cost after iteration 140: 0.693137
# Cost after iteration 141: 0.693137
# Cost after iteration 142: 0.693136
# Cost after iteration 143: 0.693136
# Cost after iteration 144: 0.693136
# Cost after iteration 145: 0.693136
# Cost after iteration 146: 0.693135
# Cost after iteration 147: 0.693135
# Cost after iteration 148: 0.693135
# Cost after iteration 149: 0.693135
# Cost after iteration 150: 0.693134
# Cost after iteration 151: 0.693134
# Cost after iteration 152: 0.693134
# Cost after iteration 153: 0.693134
# Cost after iteration 154: 0.693133
# Cost after iteration 155: 0.693133
# Cost after iteration 156: 0.693133
# Cost after iteration 157: 0.693132
# Cost after iteration 158: 0.693132
# Cost after iteration 159: 0.693132
# Cost after iteration 160: 0.693132
# Cost after iteration 161: 0.693131
# Cost after iteration 162: 0.693131
# Cost after iteration 163: 0.693131
# Cost after iteration 164: 0.693130
# Cost after iteration 165: 0.693130
# Cost after iteration 166: 0.693129
# Cost after iteration 167: 0.693129
# Cost after iteration 168: 0.693129
# Cost after iteration 169: 0.693128
# Cost after iteration 170: 0.693128
# Cost after iteration 171: 0.693127
# Cost after iteration 172: 0.693127
# Cost after iteration 173: 0.693127
# Cost after iteration 174: 0.693126
# Cost after iteration 175: 0.693126
# Cost after iteration 176: 0.693125
# Cost after iteration 177: 0.693125
# Cost after iteration 178: 0.693124
# Cost after iteration 179: 0.693124
# Cost after iteration 180: 0.693123
# Cost after iteration 181: 0.693123
# Cost after iteration 182: 0.693122
# Cost after iteration 183: 0.693122
# Cost after iteration 184: 0.693121
# Cost after iteration 185: 0.693120
# Cost after iteration 186: 0.693120
# Cost after iteration 187: 0.693119
# Cost after iteration 188: 0.693118
# Cost after iteration 189: 0.693118
# Cost after iteration 190: 0.693117
# Cost after iteration 191: 0.693116
# Cost after iteration 192: 0.693116
# Cost after iteration 193: 0.693115
# Cost after iteration 194: 0.693114
# Cost after iteration 195: 0.693113
# Cost after iteration 196: 0.693112
# Cost after iteration 197: 0.693111
# Cost after iteration 198: 0.693110
# Cost after iteration 199: 0.693109
# Cost after iteration 200: 0.693109
# Cost after iteration 201: 0.693107
# Cost after iteration 202: 0.693106
# Cost after iteration 203: 0.693105
# Cost after iteration 204: 0.693104
# Cost after iteration 205: 0.693103
# Cost after iteration 206: 0.693102
# Cost after iteration 207: 0.693100
# Cost after iteration 208: 0.693099
# Cost after iteration 209: 0.693098
# Cost after iteration 210: 0.693096
# Cost after iteration 211: 0.693095
# Cost after iteration 212: 0.693093
# Cost after iteration 213: 0.693092
# Cost after iteration 214: 0.693090
# Cost after iteration 215: 0.693088
# Cost after iteration 216: 0.693086
# Cost after iteration 217: 0.693084
# Cost after iteration 218: 0.693082
# Cost after iteration 219: 0.693080
# Cost after iteration 220: 0.693078
# Cost after iteration 221: 0.693075
# Cost after iteration 222: 0.693073
# Cost after iteration 223: 0.693070
# Cost after iteration 224: 0.693067
# Cost after iteration 225: 0.693065
# Cost after iteration 226: 0.693061
# Cost after iteration 227: 0.693058
# Cost after iteration 228: 0.693055
# Cost after iteration 229: 0.693051
# Cost after iteration 230: 0.693047
# Cost after iteration 231: 0.693043
# Cost after iteration 232: 0.693039
# Cost after iteration 233: 0.693034
# Cost after iteration 234: 0.693029
# Cost after iteration 235: 0.693024
# Cost after iteration 236: 0.693018
# Cost after iteration 237: 0.693012
# Cost after iteration 238: 0.693006
# Cost after iteration 239: 0.692999
# Cost after iteration 240: 0.692991
# Cost after iteration 241: 0.692983
# Cost after iteration 242: 0.692975
# Cost after iteration 243: 0.692965
# Cost after iteration 244: 0.692955
# Cost after iteration 245: 0.692944
# Cost after iteration 246: 0.692932
# Cost after iteration 247: 0.692919
# Cost after iteration 248: 0.692905
# Cost after iteration 249: 0.692890
# Cost after iteration 250: 0.692873
# Cost after iteration 251: 0.692854
# Cost after iteration 252: 0.692834
# Cost after iteration 253: 0.692811
# Cost after iteration 254: 0.692786
# Cost after iteration 255: 0.692758
# Cost after iteration 256: 0.692727
# Cost after iteration 257: 0.692693
# Cost after iteration 258: 0.692654
# Cost after iteration 259: 0.692611
# Cost after iteration 260: 0.692563
# Cost after iteration 261: 0.692508
# Cost after iteration 262: 0.692447
# Cost after iteration 263: 0.692377
# Cost after iteration 264: 0.692298
# Cost after iteration 265: 0.692207
# Cost after iteration 266: 0.692104
# Cost after iteration 267: 0.691986
# Cost after iteration 268: 0.691851
# Cost after iteration 269: 0.691695
# Cost after iteration 270: 0.691516
# Cost after iteration 271: 0.691310
# Cost after iteration 272: 0.691072
# Cost after iteration 273: 0.690797
# Cost after iteration 274: 0.690480
# Cost after iteration 275: 0.690115
# Cost after iteration 276: 0.689693
# Cost after iteration 277: 0.689209
# Cost after iteration 278: 0.688653
# Cost after iteration 279: 0.688017
# Cost after iteration 280: 0.687294
# Cost after iteration 281: 0.686474
# Cost after iteration 282: 0.685551
# Cost after iteration 283: 0.684517
# Cost after iteration 284: 0.683367
# Cost after iteration 285: 0.682097
# Cost after iteration 286: 0.680706
# Cost after iteration 287: 0.679193
# Cost after iteration 288: 0.677562
# Cost after iteration 289: 0.675815
# Cost after iteration 290: 0.673958
# Cost after iteration 291: 0.671998
# Cost after iteration 292: 0.669943
# Cost after iteration 293: 0.667800
# Cost after iteration 294: 0.665577
# Cost after iteration 295: 0.663283
# Cost after iteration 296: 0.660923
# Cost after iteration 297: 0.658504
# Cost after iteration 298: 0.656032
# Cost after iteration 299: 0.653512
# Cost after iteration 300: 0.650949
# Cost after iteration 301: 0.648349
# Cost after iteration 302: 0.645719
# Cost after iteration 303: 0.643068
# Cost after iteration 304: 0.640408
# Cost after iteration 305: 0.637753
# Cost after iteration 306: 0.635120
# Cost after iteration 307: 0.632523
# Cost after iteration 308: 0.629977
# Cost after iteration 309: 0.627493
# Cost after iteration 310: 0.625077
# Cost after iteration 311: 0.622733
# Cost after iteration 312: 0.620464
# Cost after iteration 313: 0.618270
# Cost after iteration 314: 0.616148
# Cost after iteration 315: 0.614098
# Cost after iteration 316: 0.612115
# Cost after iteration 317: 0.610198
# Cost after iteration 318: 0.608344
# Cost after iteration 319: 0.606548
# Cost after iteration 320: 0.604809
# Cost after iteration 321: 0.603124
# Cost after iteration 322: 0.601489
# Cost after iteration 323: 0.599902
# Cost after iteration 324: 0.598361
# Cost after iteration 325: 0.596862
# Cost after iteration 326: 0.595404
# Cost after iteration 327: 0.593984
# Cost after iteration 328: 0.592599
# Cost after iteration 329: 0.591249
# Cost after iteration 330: 0.589930
# Cost after iteration 331: 0.588642
# Cost after iteration 332: 0.587382
# Cost after iteration 333: 0.586148
# Cost after iteration 334: 0.584940
# Cost after iteration 335: 0.583755
# Cost after iteration 336: 0.582593
# Cost after iteration 337: 0.581451
# Cost after iteration 338: 0.580329
# Cost after iteration 339: 0.579226
# Cost after iteration 340: 0.578139
# Cost after iteration 341: 0.577069
# Cost after iteration 342: 0.576014
# Cost after iteration 343: 0.574973
# Cost after iteration 344: 0.573945
# Cost after iteration 345: 0.572929
# Cost after iteration 346: 0.571925
# Cost after iteration 347: 0.570932
# Cost after iteration 348: 0.569948
# Cost after iteration 349: 0.568973
# Cost after iteration 350: 0.568007
# Cost after iteration 351: 0.567049
# Cost after iteration 352: 0.566097
# Cost after iteration 353: 0.565152
# Cost after iteration 354: 0.564212
# Cost after iteration 355: 0.563278
# Cost after iteration 356: 0.562348
# Cost after iteration 357: 0.561423
# Cost after iteration 358: 0.560501
# Cost after iteration 359: 0.559582
# Cost after iteration 360: 0.558666
# Cost after iteration 361: 0.557752
# Cost after iteration 362: 0.556839
# Cost after iteration 363: 0.555928
# Cost after iteration 364: 0.555018
# Cost after iteration 365: 0.554107
# Cost after iteration 366: 0.553197
# Cost after iteration 367: 0.552286
# Cost after iteration 368: 0.551374
# Cost after iteration 369: 0.550460
# Cost after iteration 370: 0.549543
# Cost after iteration 371: 0.548623
# Cost after iteration 372: 0.547699
# Cost after iteration 373: 0.546769
# Cost after iteration 374: 0.545831
# Cost after iteration 375: 0.544883
# Cost after iteration 376: 0.543920
# Cost after iteration 377: 0.542938
# Cost after iteration 378: 0.541925
# Cost after iteration 379: 0.540865
# Cost after iteration 380: 0.539725
# Cost after iteration 381: 0.538437
# Cost after iteration 382: 0.536847
# Cost after iteration 383: 0.534561
# Cost after iteration 384: 0.530501
# Cost after iteration 385: 0.522116
# Cost after iteration 386: 0.506484
# Cost after iteration 387: 0.485194
# Cost after iteration 388: 0.465280
# Cost after iteration 389: 0.460012
# Cost after iteration 390: 0.524952
# Cost after iteration 391: 0.590483
# Cost after iteration 392: 0.558861
# Cost after iteration 393: 0.452851
# Cost after iteration 394: 0.465268
# Cost after iteration 395: 0.429463
# Cost after iteration 396: 0.422949
# Cost after iteration 397: 0.401202
# Cost after iteration 398: 0.391625
# Cost after iteration 399: 0.381733
# Cost after iteration 400: 0.375470
# Cost after iteration 401: 0.370249
# Cost after iteration 402: 0.366026
# Cost after iteration 403: 0.362266
# Cost after iteration 404: 0.358830
# Cost after iteration 405: 0.355598
# Cost after iteration 406: 0.352522
# Cost after iteration 407: 0.349571
# Cost after iteration 408: 0.346727
# Cost after iteration 409: 0.343981
# Cost after iteration 410: 0.341324
# Cost after iteration 411: 0.338752
# Cost after iteration 412: 0.336260
# Cost after iteration 413: 0.333843
# Cost after iteration 414: 0.331498
# Cost after iteration 415: 0.329222
# Cost after iteration 416: 0.327012
# Cost after iteration 417: 0.324864
# Cost after iteration 418: 0.322775
# Cost after iteration 419: 0.320744
# Cost after iteration 420: 0.318767
# Cost after iteration 421: 0.316843
# Cost after iteration 422: 0.314968
# Cost after iteration 423: 0.313141
# Cost after iteration 424: 0.311359
# Cost after iteration 425: 0.309622
# Cost after iteration 426: 0.307926
# Cost after iteration 427: 0.306271
# Cost after iteration 428: 0.304654
# Cost after iteration 429: 0.303074
# Cost after iteration 430: 0.301529
# Cost after iteration 431: 0.300019
# Cost after iteration 432: 0.298542
# Cost after iteration 433: 0.297096
# Cost after iteration 434: 0.295680
# Cost after iteration 435: 0.294293
# Cost after iteration 436: 0.292934
# Cost after iteration 437: 0.291603
# Cost after iteration 438: 0.290297
# Cost after iteration 439: 0.289016
# Cost after iteration 440: 0.287759
# Cost after iteration 441: 0.286525
# Cost after iteration 442: 0.285314
# Cost after iteration 443: 0.284124
# Cost after iteration 444: 0.282955
# Cost after iteration 445: 0.281807
# Cost after iteration 446: 0.280677
# Cost after iteration 447: 0.279567
# Cost after iteration 448: 0.278474
# Cost after iteration 449: 0.277399
# Cost after iteration 450: 0.276341
# Cost after iteration 451: 0.275299
# Cost after iteration 452: 0.274274
# Cost after iteration 453: 0.273263
# Cost after iteration 454: 0.272268
# Cost after iteration 455: 0.271287
# Cost after iteration 456: 0.270320
# Cost after iteration 457: 0.269366
# Cost after iteration 458: 0.268426
# Cost after iteration 459: 0.267498
# Cost after iteration 460: 0.266583
# Cost after iteration 461: 0.265680
# Cost after iteration 462: 0.264789
# Cost after iteration 463: 0.263909
# Cost after iteration 464: 0.263041
# Cost after iteration 465: 0.262183
# Cost after iteration 466: 0.261336
# Cost after iteration 467: 0.260499
# Cost after iteration 468: 0.259672
# Cost after iteration 469: 0.258855
# Cost after iteration 470: 0.258047
# Cost after iteration 471: 0.257249
# Cost after iteration 472: 0.256460
# Cost after iteration 473: 0.255680
# Cost after iteration 474: 0.254909
# Cost after iteration 475: 0.254146
# Cost after iteration 476: 0.253391
# Cost after iteration 477: 0.252645
# Cost after iteration 478: 0.251907
# Cost after iteration 479: 0.251177
# Cost after iteration 480: 0.250454
# Cost after iteration 481: 0.249739
# Cost after iteration 482: 0.249032
# Cost after iteration 483: 0.248332
# Cost after iteration 484: 0.247639
# Cost after iteration 485: 0.246953
# Cost after iteration 486: 0.246274
# Cost after iteration 487: 0.245602
# Cost after iteration 488: 0.244937
# Cost after iteration 489: 0.244279
# Cost after iteration 490: 0.243627
# Cost after iteration 491: 0.242982
# Cost after iteration 492: 0.242344
# Cost after iteration 493: 0.241711
# Cost after iteration 494: 0.241085
# Cost after iteration 495: 0.240466
# Cost after iteration 496: 0.239852
# Cost after iteration 497: 0.239244
# Cost after iteration 498: 0.238643
# Cost after iteration 499: 0.238047
# Cost after iteration 500: 0.237458
# Cost after iteration 501: 0.236874
# Cost after iteration 502: 0.236296
# Cost after iteration 503: 0.235724
# Cost after iteration 504: 0.235158
# Cost after iteration 505: 0.234598
# Cost after iteration 506: 0.234046
# Cost after iteration 507: 0.233503
# Cost after iteration 508: 0.232978
# Cost after iteration 509: 0.232490
# Cost after iteration 510: 0.232093
# Cost after iteration 511: 0.231940
# Cost after iteration 512: 0.232459
# Cost after iteration 513: 0.234965
# Cost after iteration 514: 0.243349
# Cost after iteration 515: 0.271346
# Cost after iteration 516: 0.368343
# Cost after iteration 517: 0.572528
# Cost after iteration 518: 0.766719
# Cost after iteration 519: 0.246098
# Cost after iteration 520: 0.239453
# Cost after iteration 521: 0.235724
# Cost after iteration 522: 0.234325
# Cost after iteration 523: 0.233400
# Cost after iteration 524: 0.232696
# Cost after iteration 525: 0.232068
# Cost after iteration 526: 0.231478
# Cost after iteration 527: 0.230908
# Cost after iteration 528: 0.230353
# Cost after iteration 529: 0.229809
# Cost after iteration 530: 0.229273
# Cost after iteration 531: 0.228745
# Cost after iteration 532: 0.228224
# Cost after iteration 533: 0.227708
# Cost after iteration 534: 0.227198
# Cost after iteration 535: 0.226693
# Cost after iteration 536: 0.226193
# Cost after iteration 537: 0.225698
# Cost after iteration 538: 0.225207
# Cost after iteration 539: 0.224720
# Cost after iteration 540: 0.224238
# Cost after iteration 541: 0.223760
# Cost after iteration 542: 0.223286
# Cost after iteration 543: 0.222817
# Cost after iteration 544: 0.222351
# Cost after iteration 545: 0.221890
# Cost after iteration 546: 0.221433
# Cost after iteration 547: 0.220981
# Cost after iteration 548: 0.220533
# Cost after iteration 549: 0.220089
# Cost after iteration 550: 0.219649
# Cost after iteration 551: 0.219214
# Cost after iteration 552: 0.218783
# Cost after iteration 553: 0.218357
# Cost after iteration 554: 0.217936
# Cost after iteration 555: 0.217518
# Cost after iteration 556: 0.217106
# Cost after iteration 557: 0.216698
# Cost after iteration 558: 0.216295
# Cost after iteration 559: 0.215897
# Cost after iteration 560: 0.215504
# Cost after iteration 561: 0.215118
# Cost after iteration 562: 0.214739
# Cost after iteration 563: 0.214372
# Cost after iteration 564: 0.214024
# Cost after iteration 565: 0.213714
# Cost after iteration 566: 0.213484
# Cost after iteration 567: 0.213437
# Cost after iteration 568: 0.213825
# Cost after iteration 569: 0.215314
# Cost after iteration 570: 0.219648
# Cost after iteration 571: 0.232216
# Cost after iteration 572: 0.269883
# Cost after iteration 573: 0.377609
# Cost after iteration 574: 0.640535
# Cost after iteration 575: 0.358723
# Cost after iteration 576: 0.411986
# Cost after iteration 577: 0.342226
# Cost after iteration 578: 0.327847
# Cost after iteration 579: 0.274554
# Cost after iteration 580: 0.255770
# Cost after iteration 581: 0.239177
# Cost after iteration 582: 0.236035
# Cost after iteration 583: 0.228805
# Cost after iteration 584: 0.227396
# Cost after iteration 585: 0.223708
# Cost after iteration 586: 0.222533
# Cost after iteration 587: 0.220460
# Cost after iteration 588: 0.219525
# Cost after iteration 589: 0.218240
# Cost after iteration 590: 0.217499
# Cost after iteration 591: 0.216610
# Cost after iteration 592: 0.216000
# Cost after iteration 593: 0.215318
# Cost after iteration 594: 0.214790
# Cost after iteration 595: 0.214223
# Cost after iteration 596: 0.213748
# Cost after iteration 597: 0.213249
# Cost after iteration 598: 0.212810
# Cost after iteration 599: 0.212354
# Cost after iteration 600: 0.211942
# Cost after iteration 601: 0.211517
# Cost after iteration 602: 0.211128
# Cost after iteration 603: 0.210728
# Cost after iteration 604: 0.210360
# Cost after iteration 605: 0.209982
# Cost after iteration 606: 0.209638
# Cost after iteration 607: 0.209283
# Cost after iteration 608: 0.208966
# Cost after iteration 609: 0.208639
# Cost after iteration 610: 0.208360
# Cost after iteration 611: 0.208070
# Cost after iteration 612: 0.207847
# Cost after iteration 613: 0.207613
# Cost after iteration 614: 0.207486
# Cost after iteration 615: 0.207349
# Cost after iteration 616: 0.207398
# Cost after iteration 617: 0.207447
# Cost after iteration 618: 0.207858
# Cost after iteration 619: 0.208308
# Cost after iteration 620: 0.209549
# Cost after iteration 621: 0.210987
# Cost after iteration 622: 0.214386
# Cost after iteration 623: 0.218695
# Cost after iteration 624: 0.228782
# Cost after iteration 625: 0.243607
# Cost after iteration 626: 0.281156
# Cost after iteration 627: 0.339481
# Cost after iteration 628: 0.513604
# Cost after iteration 629: 0.501363
# Cost after iteration 630: 0.663141
# Cost after iteration 631: 0.338968
# Cost after iteration 632: 0.303315
# Cost after iteration 633: 0.238479
# Cost after iteration 634: 0.225892
# Cost after iteration 635: 0.218002
# Cost after iteration 636: 0.215356
# Cost after iteration 637: 0.213517
# Cost after iteration 638: 0.212532
# Cost after iteration 639: 0.211776
# Cost after iteration 640: 0.211195
# Cost after iteration 641: 0.210682
# Cost after iteration 642: 0.210214
# Cost after iteration 643: 0.209770
# Cost after iteration 644: 0.209344
# Cost after iteration 645: 0.208929
# Cost after iteration 646: 0.208523
# Cost after iteration 647: 0.208125
# Cost after iteration 648: 0.207735
# Cost after iteration 649: 0.207350
# Cost after iteration 650: 0.206971
# Cost after iteration 651: 0.206598
# Cost after iteration 652: 0.206230
# Cost after iteration 653: 0.205867
# Cost after iteration 654: 0.205509
# Cost after iteration 655: 0.205157
# Cost after iteration 656: 0.204809
# Cost after iteration 657: 0.204466
# Cost after iteration 658: 0.204128
# Cost after iteration 659: 0.203794
# Cost after iteration 660: 0.203466
# Cost after iteration 661: 0.203142
# Cost after iteration 662: 0.202823
# Cost after iteration 663: 0.202509
# Cost after iteration 664: 0.202199
# Cost after iteration 665: 0.201895
# Cost after iteration 666: 0.201595
# Cost after iteration 667: 0.201299
# Cost after iteration 668: 0.201009
# Cost after iteration 669: 0.200723
# Cost after iteration 670: 0.200443
# Cost after iteration 671: 0.200166
# Cost after iteration 672: 0.199895
# Cost after iteration 673: 0.199628
# Cost after iteration 674: 0.199366
# Cost after iteration 675: 0.199109
# Cost after iteration 676: 0.198856
# Cost after iteration 677: 0.198608
# Cost after iteration 678: 0.198365
# Cost after iteration 679: 0.198126
# Cost after iteration 680: 0.197891
# Cost after iteration 681: 0.197662
# Cost after iteration 682: 0.197436
# Cost after iteration 683: 0.197216
# Cost after iteration 684: 0.196999
# Cost after iteration 685: 0.196788
# Cost after iteration 686: 0.196582
# Cost after iteration 687: 0.196383
# Cost after iteration 688: 0.196192
# Cost after iteration 689: 0.196013
# Cost after iteration 690: 0.195857
# Cost after iteration 691: 0.195743
# Cost after iteration 692: 0.195716
# Cost after iteration 693: 0.195873
# Cost after iteration 694: 0.196462
# Cost after iteration 695: 0.198001
# Cost after iteration 696: 0.202063
# Cost after iteration 697: 0.212152
# Cost after iteration 698: 0.242175
# Cost after iteration 699: 0.324309
# Cost after iteration 700: 0.571395
# Cost after iteration 701: 0.489631
# Cost after iteration 702: 0.656915
# Cost after iteration 703: 0.356583
# Cost after iteration 704: 0.413384
# Cost after iteration 705: 0.278078
# Cost after iteration 706: 0.268615
# Cost after iteration 707: 0.222005
# Cost after iteration 708: 0.216116
# Cost after iteration 709: 0.209867
# Cost after iteration 710: 0.207635
# Cost after iteration 711: 0.205850
# Cost after iteration 712: 0.204871
# Cost after iteration 713: 0.204094
# Cost after iteration 714: 0.203512
# Cost after iteration 715: 0.203004
# Cost after iteration 716: 0.202556
# Cost after iteration 717: 0.202138
# Cost after iteration 718: 0.201746
# Cost after iteration 719: 0.201370
# Cost after iteration 720: 0.201009
# Cost after iteration 721: 0.200659
# Cost after iteration 722: 0.200320
# Cost after iteration 723: 0.199990
# Cost after iteration 724: 0.199669
# Cost after iteration 725: 0.199356
# Cost after iteration 726: 0.199051
# Cost after iteration 727: 0.198752
# Cost after iteration 728: 0.198461
# Cost after iteration 729: 0.198176
# Cost after iteration 730: 0.197898
# Cost after iteration 731: 0.197626
# Cost after iteration 732: 0.197359
# Cost after iteration 733: 0.197099
# Cost after iteration 734: 0.196844
# Cost after iteration 735: 0.196595
# Cost after iteration 736: 0.196351
# Cost after iteration 737: 0.196112
# Cost after iteration 738: 0.195879
# Cost after iteration 739: 0.195650
# Cost after iteration 740: 0.195427
# Cost after iteration 741: 0.195209
# Cost after iteration 742: 0.194995
# Cost after iteration 743: 0.194786
# Cost after iteration 744: 0.194581
# Cost after iteration 745: 0.194382
# Cost after iteration 746: 0.194186
# Cost after iteration 747: 0.193996
# Cost after iteration 748: 0.193809
# Cost after iteration 749: 0.193627
# Cost after iteration 750: 0.193450
# Cost after iteration 751: 0.193277
# Cost after iteration 752: 0.193108
# Cost after iteration 753: 0.192946
# Cost after iteration 754: 0.192789
# Cost after iteration 755: 0.192640
# Cost after iteration 756: 0.192503
# Cost after iteration 757: 0.192382
# Cost after iteration 758: 0.192290
# Cost after iteration 759: 0.192246
# Cost after iteration 760: 0.192298
# Cost after iteration 761: 0.192520
# Cost after iteration 762: 0.193114
# Cost after iteration 763: 0.194384
# Cost after iteration 764: 0.197345
# Cost after iteration 765: 0.203473
# Cost after iteration 766: 0.219359
# Cost after iteration 767: 0.256397
# Cost after iteration 768: 0.381036
# Cost after iteration 769: 0.530103
# Cost after iteration 770: 0.808809
# Cost after iteration 771: 0.331030
# Cost after iteration 772: 0.417382
# Cost after iteration 773: 0.258605
# Cost after iteration 774: 0.249987
# Cost after iteration 775: 0.213539
# Cost after iteration 776: 0.208539
# Cost after iteration 777: 0.203894
# Cost after iteration 778: 0.202055
# Cost after iteration 779: 0.200727
# Cost after iteration 780: 0.199948
# Cost after iteration 781: 0.199342
# Cost after iteration 782: 0.198865
# Cost after iteration 783: 0.198445
# Cost after iteration 784: 0.198065
# Cost after iteration 785: 0.197711
# Cost after iteration 786: 0.197376
# Cost after iteration 787: 0.197057
# Cost after iteration 788: 0.196750
# Cost after iteration 789: 0.196454
# Cost after iteration 790: 0.196168
# Cost after iteration 791: 0.195892
# Cost after iteration 792: 0.195625
# Cost after iteration 793: 0.195365
# Cost after iteration 794: 0.195114
# Cost after iteration 795: 0.194870
# Cost after iteration 796: 0.194633
# Cost after iteration 797: 0.194403
# Cost after iteration 798: 0.194179
# Cost after iteration 799: 0.193961
# Cost after iteration 800: 0.193749
# Cost after iteration 801: 0.193543
# Cost after iteration 802: 0.193343
# Cost after iteration 803: 0.193147
# Cost after iteration 804: 0.192957
# Cost after iteration 805: 0.192772
# Cost after iteration 806: 0.192591
# Cost after iteration 807: 0.192416
# Cost after iteration 808: 0.192244
# Cost after iteration 809: 0.192077
# Cost after iteration 810: 0.191915
# Cost after iteration 811: 0.191756
# Cost after iteration 812: 0.191602
# Cost after iteration 813: 0.191451
# Cost after iteration 814: 0.191304
# Cost after iteration 815: 0.191161
# Cost after iteration 816: 0.191022
# Cost after iteration 817: 0.190886
# Cost after iteration 818: 0.190755
# Cost after iteration 819: 0.190627
# Cost after iteration 820: 0.190503
# Cost after iteration 821: 0.190384
# Cost after iteration 822: 0.190271
# Cost after iteration 823: 0.190166
# Cost after iteration 824: 0.190072
# Cost after iteration 825: 0.189998
# Cost after iteration 826: 0.189956
# Cost after iteration 827: 0.189970
# Cost after iteration 828: 0.190097
# Cost after iteration 829: 0.190418
# Cost after iteration 830: 0.191174
# Cost after iteration 831: 0.192680
# Cost after iteration 832: 0.196118
# Cost after iteration 833: 0.202929
# Cost after iteration 834: 0.220819
# Cost after iteration 835: 0.260715
# Cost after iteration 836: 0.397241
# Cost after iteration 837: 0.519716
# Cost after iteration 838: 0.729963
# Cost after iteration 839: 0.320053
# Cost after iteration 840: 0.387976
# Cost after iteration 841: 0.271626
# Cost after iteration 842: 0.277167
# Cost after iteration 843: 0.219059
# Cost after iteration 844: 0.213988
# Cost after iteration 845: 0.204883
# Cost after iteration 846: 0.202291
# Cost after iteration 847: 0.199663
# Cost after iteration 848: 0.198467
# Cost after iteration 849: 0.197492
# Cost after iteration 850: 0.196881
# Cost after iteration 851: 0.196374
# Cost after iteration 852: 0.195972
# Cost after iteration 853: 0.195614
# Cost after iteration 854: 0.195293
# Cost after iteration 855: 0.194994
# Cost after iteration 856: 0.194712
# Cost after iteration 857: 0.194444
# Cost after iteration 858: 0.194188
# Cost after iteration 859: 0.193942
# Cost after iteration 860: 0.193704
# Cost after iteration 861: 0.193475
# Cost after iteration 862: 0.193253
# Cost after iteration 863: 0.193038
# Cost after iteration 864: 0.192830
# Cost after iteration 865: 0.192629
# Cost after iteration 866: 0.192433
# Cost after iteration 867: 0.192243
# Cost after iteration 868: 0.192059
# Cost after iteration 869: 0.191879
# Cost after iteration 870: 0.191705
# Cost after iteration 871: 0.191536
# Cost after iteration 872: 0.191372
# Cost after iteration 873: 0.191212
# Cost after iteration 874: 0.191057
# Cost after iteration 875: 0.190906
# Cost after iteration 876: 0.190759
# Cost after iteration 877: 0.190616
# Cost after iteration 878: 0.190476
# Cost after iteration 879: 0.190341
# Cost after iteration 880: 0.190209
# Cost after iteration 881: 0.190081
# Cost after iteration 882: 0.189956
# Cost after iteration 883: 0.189835
# Cost after iteration 884: 0.189717
# Cost after iteration 885: 0.189602
# Cost after iteration 886: 0.189491
# Cost after iteration 887: 0.189383
# Cost after iteration 888: 0.189278
# Cost after iteration 889: 0.189178
# Cost after iteration 890: 0.189081
# Cost after iteration 891: 0.188989
# Cost after iteration 892: 0.188904
# Cost after iteration 893: 0.188826
# Cost after iteration 894: 0.188760
# Cost after iteration 895: 0.188710
# Cost after iteration 896: 0.188689
# Cost after iteration 897: 0.188709
# Cost after iteration 898: 0.188807
# Cost after iteration 899: 0.189018
# Cost after iteration 900: 0.189476
# Cost after iteration 901: 0.190271
# Cost after iteration 902: 0.191916
# Cost after iteration 903: 0.194662
# Cost after iteration 904: 0.200775
# Cost after iteration 905: 0.211174
# Cost after iteration 906: 0.239130
# Cost after iteration 907: 0.291163
# Cost after iteration 908: 0.469261
# Cost after iteration 909: 0.553573
# Cost after iteration 910: 0.978440
# Cost after iteration 911: 0.339524
# Cost after iteration 912: 0.354039
# Cost after iteration 913: 0.214118
# Cost after iteration 914: 0.205508
# Cost after iteration 915: 0.201271
# Cost after iteration 916: 0.199745
# Cost after iteration 917: 0.198905
# Cost after iteration 918: 0.198331
# Cost after iteration 919: 0.197851
# Cost after iteration 920: 0.197416
# Cost after iteration 921: 0.197010
# Cost after iteration 922: 0.196625
# Cost after iteration 923: 0.196259
# Cost after iteration 924: 0.195909
# Cost after iteration 925: 0.195575
# Cost after iteration 926: 0.195255
# Cost after iteration 927: 0.194949
# Cost after iteration 928: 0.194656
# Cost after iteration 929: 0.194374
# Cost after iteration 930: 0.194104
# Cost after iteration 931: 0.193845
# Cost after iteration 932: 0.193595
# Cost after iteration 933: 0.193355
# Cost after iteration 934: 0.193124
# Cost after iteration 935: 0.192901
# Cost after iteration 936: 0.192686
# Cost after iteration 937: 0.192479
# Cost after iteration 938: 0.192279
# Cost after iteration 939: 0.192085
# Cost after iteration 940: 0.191899
# Cost after iteration 941: 0.191718
# Cost after iteration 942: 0.191543
# Cost after iteration 943: 0.191374
# Cost after iteration 944: 0.191210
# Cost after iteration 945: 0.191051
# Cost after iteration 946: 0.190897
# Cost after iteration 947: 0.190748
# Cost after iteration 948: 0.190603
# Cost after iteration 949: 0.190462
# Cost after iteration 950: 0.190326
# Cost after iteration 951: 0.190193
# Cost after iteration 952: 0.190065
# Cost after iteration 953: 0.189940
# Cost after iteration 954: 0.189818
# Cost after iteration 955: 0.189700
# Cost after iteration 956: 0.189585
# Cost after iteration 957: 0.189473
# Cost after iteration 958: 0.189365
# Cost after iteration 959: 0.189259
# Cost after iteration 960: 0.189156
# Cost after iteration 961: 0.189056
# Cost after iteration 962: 0.188958
# Cost after iteration 963: 0.188863
# Cost after iteration 964: 0.188770
# Cost after iteration 965: 0.188680
# Cost after iteration 966: 0.188592
# Cost after iteration 967: 0.188507
# Cost after iteration 968: 0.188423
# Cost after iteration 969: 0.188342
# Cost after iteration 970: 0.188263
# Cost after iteration 971: 0.188185
# Cost after iteration 972: 0.188110
# Cost after iteration 973: 0.188036
# Cost after iteration 974: 0.187964
# Cost after iteration 975: 0.187894
# Cost after iteration 976: 0.187825
# Cost after iteration 977: 0.187758
# Cost after iteration 978: 0.187693
# Cost after iteration 979: 0.187629
# Cost after iteration 980: 0.187567
# Cost after iteration 981: 0.187506
# Cost after iteration 982: 0.187446
# Cost after iteration 983: 0.187388
# Cost after iteration 984: 0.187331
# Cost after iteration 985: 0.187275
# Cost after iteration 986: 0.187221
# Cost after iteration 987: 0.187168
# Cost after iteration 988: 0.187116
# Cost after iteration 989: 0.187064
# Cost after iteration 990: 0.187015
# Cost after iteration 991: 0.186966
# Cost after iteration 992: 0.186918
# Cost after iteration 993: 0.186871
# Cost after iteration 994: 0.186826
# Cost after iteration 995: 0.186781
# Cost after iteration 996: 0.186738
# Cost after iteration 997: 0.186698
# Cost after iteration 998: 0.186661
# Cost after iteration 999: 0.186631
# Cost after iteration 1000: 0.186614
# Cost after iteration 1001: 0.186621
# Cost after iteration 1002: 0.186681
# Cost after iteration 1003: 0.186847
# Cost after iteration 1004: 0.187249
# Cost after iteration 1005: 0.188119
# Cost after iteration 1006: 0.190148
# Cost after iteration 1007: 0.194388
# Cost after iteration 1008: 0.205301
# Cost after iteration 1009: 0.229526
# Cost after iteration 1010: 0.316975
# Cost after iteration 1011: 0.463380
# Cost after iteration 1012: 0.788284
# Cost after iteration 1013: 0.360420
# Cost after iteration 1014: 0.527979
# Cost after iteration 1015: 0.297998
# Cost after iteration 1016: 0.292654
# Cost after iteration 1017: 0.221552
# Cost after iteration 1018: 0.210469
# Cost after iteration 1019: 0.201964
# Cost after iteration 1020: 0.198194
# Cost after iteration 1021: 0.196027
# Cost after iteration 1022: 0.194910
# Cost after iteration 1023: 0.194200
# Cost after iteration 1024: 0.193713
# Cost after iteration 1025: 0.193326
# Cost after iteration 1026: 0.192997
# Cost after iteration 1027: 0.192700
# Cost after iteration 1028: 0.192426
# Cost after iteration 1029: 0.192170
# Cost after iteration 1030: 0.191928
# Cost after iteration 1031: 0.191698
# Cost after iteration 1032: 0.191479
# Cost after iteration 1033: 0.191271
# Cost after iteration 1034: 0.191072
# Cost after iteration 1035: 0.190881
# Cost after iteration 1036: 0.190699
# Cost after iteration 1037: 0.190524
# Cost after iteration 1038: 0.190357
# Cost after iteration 1039: 0.190196
# Cost after iteration 1040: 0.190042
# Cost after iteration 1041: 0.189894
# Cost after iteration 1042: 0.189752
# Cost after iteration 1043: 0.189615
# Cost after iteration 1044: 0.189483
# Cost after iteration 1045: 0.189357
# Cost after iteration 1046: 0.189234
# Cost after iteration 1047: 0.189116
# Cost after iteration 1048: 0.189003
# Cost after iteration 1049: 0.188893
# Cost after iteration 1050: 0.188787
# Cost after iteration 1051: 0.188684
# Cost after iteration 1052: 0.188585
# Cost after iteration 1053: 0.188489
# Cost after iteration 1054: 0.188397
# Cost after iteration 1055: 0.188307
# Cost after iteration 1056: 0.188220
# Cost after iteration 1057: 0.188135
# Cost after iteration 1058: 0.188054
# Cost after iteration 1059: 0.187974
# Cost after iteration 1060: 0.187897
# Cost after iteration 1061: 0.187822
# Cost after iteration 1062: 0.187750
# Cost after iteration 1063: 0.187679
# Cost after iteration 1064: 0.187611
# Cost after iteration 1065: 0.187544
# Cost after iteration 1066: 0.187479
# Cost after iteration 1067: 0.187417
# Cost after iteration 1068: 0.187355
# Cost after iteration 1069: 0.187296
# Cost after iteration 1070: 0.187238
# Cost after iteration 1071: 0.187182
# Cost after iteration 1072: 0.187128
# Cost after iteration 1073: 0.187077
# Cost after iteration 1074: 0.187027
# Cost after iteration 1075: 0.186981
# Cost after iteration 1076: 0.186939
# Cost after iteration 1077: 0.186904
# Cost after iteration 1078: 0.186877
# Cost after iteration 1079: 0.186866
# Cost after iteration 1080: 0.186879
# Cost after iteration 1081: 0.186931
# Cost after iteration 1082: 0.187056
# Cost after iteration 1083: 0.187292
# Cost after iteration 1084: 0.187758
# Cost after iteration 1085: 0.188558
# Cost after iteration 1086: 0.190147
# Cost after iteration 1087: 0.192802
# Cost after iteration 1088: 0.198525
# Cost after iteration 1089: 0.208160
# Cost after iteration 1090: 0.234078
# Cost after iteration 1091: 0.280851
# Cost after iteration 1092: 0.443941
# Cost after iteration 1093: 0.511285
# Cost after iteration 1094: 0.791304
# Cost after iteration 1095: 0.370332
# Cost after iteration 1096: 0.446448
# Cost after iteration 1097: 0.238865
# Cost after iteration 1098: 0.221518
# Cost after iteration 1099: 0.203671
# Cost after iteration 1100: 0.199243
# Cost after iteration 1101: 0.196742
# Cost after iteration 1102: 0.195698
# Cost after iteration 1103: 0.195060
# Cost after iteration 1104: 0.194621
# Cost after iteration 1105: 0.194258
# Cost after iteration 1106: 0.193936
# Cost after iteration 1107: 0.193636
# Cost after iteration 1108: 0.193353
# Cost after iteration 1109: 0.193085
# Cost after iteration 1110: 0.192829
# Cost after iteration 1111: 0.192584
# Cost after iteration 1112: 0.192349
# Cost after iteration 1113: 0.192125
# Cost after iteration 1114: 0.191910
# Cost after iteration 1115: 0.191703
# Cost after iteration 1116: 0.191505
# Cost after iteration 1117: 0.191315
# Cost after iteration 1118: 0.191132
# Cost after iteration 1119: 0.190956
# Cost after iteration 1120: 0.190787
# Cost after iteration 1121: 0.190625
# Cost after iteration 1122: 0.190468
# Cost after iteration 1123: 0.190317
# Cost after iteration 1124: 0.190172
# Cost after iteration 1125: 0.190031
# Cost after iteration 1126: 0.189896
# Cost after iteration 1127: 0.189765
# Cost after iteration 1128: 0.189639
# Cost after iteration 1129: 0.189517
# Cost after iteration 1130: 0.189399
# Cost after iteration 1131: 0.189285
# Cost after iteration 1132: 0.189175
# Cost after iteration 1133: 0.189068
# Cost after iteration 1134: 0.188964
# Cost after iteration 1135: 0.188864
# Cost after iteration 1136: 0.188767
# Cost after iteration 1137: 0.188673
# Cost after iteration 1138: 0.188582
# Cost after iteration 1139: 0.188493
# Cost after iteration 1140: 0.188407
# Cost after iteration 1141: 0.188324
# Cost after iteration 1142: 0.188243
# Cost after iteration 1143: 0.188164
# Cost after iteration 1144: 0.188088
# Cost after iteration 1145: 0.188013
# Cost after iteration 1146: 0.187941
# Cost after iteration 1147: 0.187871
# Cost after iteration 1148: 0.187802
# Cost after iteration 1149: 0.187736
# Cost after iteration 1150: 0.187671
# Cost after iteration 1151: 0.187608
# Cost after iteration 1152: 0.187547
# Cost after iteration 1153: 0.187487
# Cost after iteration 1154: 0.187429
# Cost after iteration 1155: 0.187372
# Cost after iteration 1156: 0.187317
# Cost after iteration 1157: 0.187263
# Cost after iteration 1158: 0.187210
# Cost after iteration 1159: 0.187159
# Cost after iteration 1160: 0.187108
# Cost after iteration 1161: 0.187060
# Cost after iteration 1162: 0.187012
# Cost after iteration 1163: 0.186965
# Cost after iteration 1164: 0.186920
# Cost after iteration 1165: 0.186875
# Cost after iteration 1166: 0.186832
# Cost after iteration 1167: 0.186789
# Cost after iteration 1168: 0.186748
# Cost after iteration 1169: 0.186707
# Cost after iteration 1170: 0.186667
# Cost after iteration 1171: 0.186629
# Cost after iteration 1172: 0.186591
# Cost after iteration 1173: 0.186553
# Cost after iteration 1174: 0.186517
# Cost after iteration 1175: 0.186481
# Cost after iteration 1176: 0.186446
# Cost after iteration 1177: 0.186412
# Cost after iteration 1178: 0.186379
# Cost after iteration 1179: 0.186346
# Cost after iteration 1180: 0.186314
# Cost after iteration 1181: 0.186283
# Cost after iteration 1182: 0.186253
# Cost after iteration 1183: 0.186224
# Cost after iteration 1184: 0.186196
# Cost after iteration 1185: 0.186172
# Cost after iteration 1186: 0.186151
# Cost after iteration 1187: 0.186138
# Cost after iteration 1188: 0.186137
# Cost after iteration 1189: 0.186159
# Cost after iteration 1190: 0.186226
# Cost after iteration 1191: 0.186367
# Cost after iteration 1192: 0.186680
# Cost after iteration 1193: 0.187249
# Cost after iteration 1194: 0.188512
# Cost after iteration 1195: 0.190677
# Cost after iteration 1196: 0.195979
# Cost after iteration 1197: 0.204571
# Cost after iteration 1198: 0.229045
# Cost after iteration 1199: 0.260803
# Cost after iteration 1200: 0.383905
# Cost after iteration 1201: 0.461610
# Cost after iteration 1202: 1.026068
# Cost after iteration 1203: 0.349987
# Cost after iteration 1204: 0.357690
# Cost after iteration 1205: 0.252639
# Cost after iteration 1206: 0.232661
# Cost after iteration 1207: 0.212587
# Cost after iteration 1208: 0.203132
# Cost after iteration 1209: 0.198402
# Cost after iteration 1210: 0.196052
# Cost after iteration 1211: 0.194922
# Cost after iteration 1212: 0.194271
# Cost after iteration 1213: 0.193816
# Cost after iteration 1214: 0.193444
# Cost after iteration 1215: 0.193115
# Cost after iteration 1216: 0.192812
# Cost after iteration 1217: 0.192528
# Cost after iteration 1218: 0.192260
# Cost after iteration 1219: 0.192007
# Cost after iteration 1220: 0.191766
# Cost after iteration 1221: 0.191537
# Cost after iteration 1222: 0.191319
# Cost after iteration 1223: 0.191112
# Cost after iteration 1224: 0.190915
# Cost after iteration 1225: 0.190727
# Cost after iteration 1226: 0.190547
# Cost after iteration 1227: 0.190376
# Cost after iteration 1228: 0.190213
# Cost after iteration 1229: 0.190056
# Cost after iteration 1230: 0.189907
# Cost after iteration 1231: 0.189764
# Cost after iteration 1232: 0.189627
# Cost after iteration 1233: 0.189496
# Cost after iteration 1234: 0.189370
# Cost after iteration 1235: 0.189249
# Cost after iteration 1236: 0.189133
# Cost after iteration 1237: 0.189022
# Cost after iteration 1238: 0.188914
# Cost after iteration 1239: 0.188811
# Cost after iteration 1240: 0.188712
# Cost after iteration 1241: 0.188616
# Cost after iteration 1242: 0.188524
# Cost after iteration 1243: 0.188435
# Cost after iteration 1244: 0.188350
# Cost after iteration 1245: 0.188267
# Cost after iteration 1246: 0.188187
# Cost after iteration 1247: 0.188109
# Cost after iteration 1248: 0.188034
# Cost after iteration 1249: 0.187962
# Cost after iteration 1250: 0.187892
# Cost after iteration 1251: 0.187824
# Cost after iteration 1252: 0.187758
# Cost after iteration 1253: 0.187694
# Cost after iteration 1254: 0.187632
# Cost after iteration 1255: 0.187571
# Cost after iteration 1256: 0.187513
# Cost after iteration 1257: 0.187456
# Cost after iteration 1258: 0.187401
# Cost after iteration 1259: 0.187347
# Cost after iteration 1260: 0.187295
# Cost after iteration 1261: 0.187244
# Cost after iteration 1262: 0.187194
# Cost after iteration 1263: 0.187146
# Cost after iteration 1264: 0.187099
# Cost after iteration 1265: 0.187053
# Cost after iteration 1266: 0.187008
# Cost after iteration 1267: 0.186964
# Cost after iteration 1268: 0.186922
# Cost after iteration 1269: 0.186880
# Cost after iteration 1270: 0.186840
# Cost after iteration 1271: 0.186800
# Cost after iteration 1272: 0.186761
# Cost after iteration 1273: 0.186723
# Cost after iteration 1274: 0.186686
# Cost after iteration 1275: 0.186650
# Cost after iteration 1276: 0.186614
# Cost after iteration 1277: 0.186580
# Cost after iteration 1278: 0.186546
# Cost after iteration 1279: 0.186512
# Cost after iteration 1280: 0.186480
# Cost after iteration 1281: 0.186448
# Cost after iteration 1282: 0.186417
# Cost after iteration 1283: 0.186386
# Cost after iteration 1284: 0.186356
# Cost after iteration 1285: 0.186327
# Cost after iteration 1286: 0.186299
# Cost after iteration 1287: 0.186271
# Cost after iteration 1288: 0.186244
# Cost after iteration 1289: 0.186219
# Cost after iteration 1290: 0.186196
# Cost after iteration 1291: 0.186175
# Cost after iteration 1292: 0.186159
# Cost after iteration 1293: 0.186151
# Cost after iteration 1294: 0.186156
# Cost after iteration 1295: 0.186183
# Cost after iteration 1296: 0.186251
# Cost after iteration 1297: 0.186386
# Cost after iteration 1298: 0.186656
# Cost after iteration 1299: 0.187138
# Cost after iteration 1300: 0.188095
# Cost after iteration 1301: 0.189731
# Cost after iteration 1302: 0.193181
# Cost after iteration 1303: 0.198902
# Cost after iteration 1304: 0.212764
# Cost after iteration 1305: 0.235677
# Cost after iteration 1306: 0.311325
# Cost after iteration 1307: 0.414314
# Cost after iteration 1308: 0.813177
# Cost after iteration 1309: 0.461656
# Cost after iteration 1310: 0.662628
# Cost after iteration 1311: 0.306293
# Cost after iteration 1312: 0.270086
# Cost after iteration 1313: 0.219245
# Cost after iteration 1314: 0.204315
# Cost after iteration 1315: 0.198650
# Cost after iteration 1316: 0.196539
# Cost after iteration 1317: 0.195670
# Cost after iteration 1318: 0.195153
# Cost after iteration 1319: 0.194747
# Cost after iteration 1320: 0.194387
# Cost after iteration 1321: 0.194052
# Cost after iteration 1322: 0.193736
# Cost after iteration 1323: 0.193435
# Cost after iteration 1324: 0.193150
# Cost after iteration 1325: 0.192878
# Cost after iteration 1326: 0.192618
# Cost after iteration 1327: 0.192371
# Cost after iteration 1328: 0.192135
# Cost after iteration 1329: 0.191910
# Cost after iteration 1330: 0.191694
# Cost after iteration 1331: 0.191489
# Cost after iteration 1332: 0.191292
# Cost after iteration 1333: 0.191105
# Cost after iteration 1334: 0.190925
# Cost after iteration 1335: 0.190753
# Cost after iteration 1336: 0.190588
# Cost after iteration 1337: 0.190430
# Cost after iteration 1338: 0.190278
# Cost after iteration 1339: 0.190133
# Cost after iteration 1340: 0.189993
# Cost after iteration 1341: 0.189859
# Cost after iteration 1342: 0.189730
# Cost after iteration 1343: 0.189606
# Cost after iteration 1344: 0.189487
# Cost after iteration 1345: 0.189372
# Cost after iteration 1346: 0.189261
# Cost after iteration 1347: 0.189154
# Cost after iteration 1348: 0.189052
# Cost after iteration 1349: 0.188952
# Cost after iteration 1350: 0.188857
# Cost after iteration 1351: 0.188764
# Cost after iteration 1352: 0.188675
# Cost after iteration 1353: 0.188589
# Cost after iteration 1354: 0.188505
# Cost after iteration 1355: 0.188424
# Cost after iteration 1356: 0.188346
# Cost after iteration 1357: 0.188270
# Cost after iteration 1358: 0.188197
# Cost after iteration 1359: 0.188126
# Cost after iteration 1360: 0.188057
# Cost after iteration 1361: 0.187990
# Cost after iteration 1362: 0.187925
# Cost after iteration 1363: 0.187862
# ...
# Cost after iteration 2560: 0.236155
# Cost after iteration 2561: 0.230018
# Cost after iteration 2562: 0.261869
# Cost after iteration 2563: 0.232472
# Cost after iteration 2564: 0.253309
# Cost after iteration 2565: 0.220932
# Cost after iteration 2566: 0.227613
# Cost after iteration 2567: 0.212103
# Cost after iteration 2568: 0.214476
# Cost after iteration 2569: 0.207502
# Cost after iteration 2570: 0.208754
# Cost after iteration 2571: 0.205163
# Cost after iteration 2572: 0.206289
# Cost after iteration 2573: 0.204332
# Cost after iteration 2574: 0.205684
# Cost after iteration 2575: 0.204390
# Cost after iteration 2576: 0.205923
# Cost after iteration 2577: 0.204670
# Cost after iteration 2578: 0.206120
# Cost after iteration 2579: 0.204563
# Cost after iteration 2580: 0.205595
# Cost after iteration 2581: 0.203633
# Cost after iteration 2582: 0.203991
# Cost after iteration 2583: 0.201749
# Cost after iteration 2584: 0.201411
# Cost after iteration 2585: 0.199177
# Cost after iteration 2586: 0.198391
# Cost after iteration 2587: 0.196462
# Cost after iteration 2588: 0.195574
# Cost after iteration 2589: 0.194098
# Cost after iteration 2590: 0.193339
# Cost after iteration 2591: 0.192301
# Cost after iteration 2592: 0.191739
# Cost after iteration 2593: 0.191038
# Cost after iteration 2594: 0.190653
# Cost after iteration 2595: 0.190183
# Cost after iteration 2596: 0.189930
# Cost after iteration 2597: 0.189610
# Cost after iteration 2598: 0.189449
# Cost after iteration 2599: 0.189226
# Cost after iteration 2600: 0.189132
# Cost after iteration 2601: 0.188973
# Cost after iteration 2602: 0.188929
# Cost after iteration 2603: 0.188817
# Cost after iteration 2604: 0.188816
# Cost after iteration 2605: 0.188740
# Cost after iteration 2606: 0.188785
# Cost after iteration 2607: 0.188740
# Cost after iteration 2608: 0.188840
# Cost after iteration 2609: 0.188829
# Cost after iteration 2610: 0.189006
# Cost after iteration 2611: 0.189036
# Cost after iteration 2612: 0.189327
# Cost after iteration 2613: 0.189414
# Cost after iteration 2614: 0.189893
# Cost after iteration 2615: 0.190065
# Cost after iteration 2616: 0.190867
# Cost after iteration 2617: 0.191180
# Cost after iteration 2618: 0.192570
# Cost after iteration 2619: 0.193127
# Cost after iteration 2620: 0.195642
# Cost after iteration 2621: 0.196628
# Cost after iteration 2622: 0.201344
# Cost after iteration 2623: 0.202887
# Cost after iteration 2624: 0.211652
# Cost after iteration 2625: 0.212574
# Cost after iteration 2626: 0.226968
# Cost after iteration 2627: 0.222168
# Cost after iteration 2628: 0.239696
# Cost after iteration 2629: 0.226311
# Cost after iteration 2630: 0.241050
# Cost after iteration 2631: 0.226616
# Cost after iteration 2632: 0.237898
# Cost after iteration 2633: 0.228748
# Cost after iteration 2634: 0.240728
# Cost after iteration 2635: 0.236454
# Cost after iteration 2636: 0.254911
# Cost after iteration 2637: 0.251886
# Cost after iteration 2638: 0.281714
# Cost after iteration 2639: 0.266813
# Cost after iteration 2640: 0.295376
# Cost after iteration 2641: 0.258563
# Cost after iteration 2642: 0.263109
# Cost after iteration 2643: 0.230653
# Cost after iteration 2644: 0.219855
# Cost after iteration 2645: 0.205315
# Cost after iteration 2646: 0.199071
# Cost after iteration 2647: 0.194568
# Cost after iteration 2648: 0.192846
# Cost after iteration 2649: 0.191534
# Cost after iteration 2650: 0.190958
# Cost after iteration 2651: 0.190445
# Cost after iteration 2652: 0.190164
# Cost after iteration 2653: 0.189902
# Cost after iteration 2654: 0.189727
# Cost after iteration 2655: 0.189563
# Cost after iteration 2656: 0.189434
# Cost after iteration 2657: 0.189314
# Cost after iteration 2658: 0.189209
# Cost after iteration 2659: 0.189111
# Cost after iteration 2660: 0.189021
# Cost after iteration 2661: 0.188935
# Cost after iteration 2662: 0.188854
# Cost after iteration 2663: 0.188777
# Cost after iteration 2664: 0.188704
# Cost after iteration 2665: 0.188633
# Cost after iteration 2666: 0.188566
# Cost after iteration 2667: 0.188500
# Cost after iteration 2668: 0.188437
# Cost after iteration 2669: 0.188376
# Cost after iteration 2670: 0.188318
# Cost after iteration 2671: 0.188261
# Cost after iteration 2672: 0.188206
# Cost after iteration 2673: 0.188152
# Cost after iteration 2674: 0.188101
# Cost after iteration 2675: 0.188050
# Cost after iteration 2676: 0.188002
# Cost after iteration 2677: 0.187955
# Cost after iteration 2678: 0.187909
# Cost after iteration 2679: 0.187865
# Cost after iteration 2680: 0.187822
# Cost after iteration 2681: 0.187781
# Cost after iteration 2682: 0.187741
# Cost after iteration 2683: 0.187703
# Cost after iteration 2684: 0.187666
# Cost after iteration 2685: 0.187631
# Cost after iteration 2686: 0.187598
# Cost after iteration 2687: 0.187567
# Cost after iteration 2688: 0.187539
# Cost after iteration 2689: 0.187513
# Cost after iteration 2690: 0.187493
# Cost after iteration 2691: 0.187474
# Cost after iteration 2692: 0.187466
# Cost after iteration 2693: 0.187461
# Cost after iteration 2694: 0.187475
# Cost after iteration 2695: 0.187493
# Cost after iteration 2696: 0.187550
# Cost after iteration 2697: 0.187613
# Cost after iteration 2698: 0.187760
# Cost after iteration 2699: 0.187912
# Cost after iteration 2700: 0.188259
# Cost after iteration 2701: 0.188595
# Cost after iteration 2702: 0.189418
# Cost after iteration 2703: 0.190159
# Cost after iteration 2704: 0.192200
# Cost after iteration 2705: 0.193915
# Cost after iteration 2706: 0.199304
# Cost after iteration 2707: 0.203325
# Cost after iteration 2708: 0.217775
# Cost after iteration 2709: 0.222369
# Cost after iteration 2710: 0.254398
# Cost after iteration 2711: 0.238594
# Cost after iteration 2712: 0.276196
# Cost after iteration 2713: 0.233914
# Cost after iteration 2714: 0.250484
# Cost after iteration 2715: 0.218524
# Cost after iteration 2716: 0.222624
# Cost after iteration 2717: 0.211399
# Cost after iteration 2718: 0.213377
# Cost after iteration 2719: 0.208628
# Cost after iteration 2720: 0.210556
# Cost after iteration 2721: 0.208334
# Cost after iteration 2722: 0.210931
# Cost after iteration 2723: 0.209653
# Cost after iteration 2724: 0.213030
# Cost after iteration 2725: 0.211641
# Cost after iteration 2726: 0.215410
# Cost after iteration 2727: 0.213126
# Cost after iteration 2728: 0.216409
# Cost after iteration 2729: 0.212781
# Cost after iteration 2730: 0.214412
# Cost after iteration 2731: 0.209660
# Cost after iteration 2732: 0.209040
# Cost after iteration 2733: 0.204178
# Cost after iteration 2734: 0.202129
# Cost after iteration 2735: 0.198327
# Cost after iteration 2736: 0.196330
# Cost after iteration 2737: 0.193983
# Cost after iteration 2738: 0.192683
# Cost after iteration 2739: 0.191420
# Cost after iteration 2740: 0.190697
# Cost after iteration 2741: 0.190033
# Cost after iteration 2742: 0.189641
# Cost after iteration 2743: 0.189273
# Cost after iteration 2744: 0.189048
# Cost after iteration 2745: 0.188826
# Cost after iteration 2746: 0.188687
# Cost after iteration 2747: 0.188540
# Cost after iteration 2748: 0.188446
# Cost after iteration 2749: 0.188340
# Cost after iteration 2750: 0.188274
# Cost after iteration 2751: 0.188194
# Cost after iteration 2752: 0.188145
# Cost after iteration 2753: 0.188082
# Cost after iteration 2754: 0.188048
# Cost after iteration 2755: 0.187997
# Cost after iteration 2756: 0.187976
# Cost after iteration 2757: 0.187938
# Cost after iteration 2758: 0.187932
# Cost after iteration 2759: 0.187905
# Cost after iteration 2760: 0.187919
# Cost after iteration 2761: 0.187907
# Cost after iteration 2762: 0.187950
# Cost after iteration 2763: 0.187957
# Cost after iteration 2764: 0.188043
# Cost after iteration 2765: 0.188079
# Cost after iteration 2766: 0.188239
# Cost after iteration 2767: 0.188321
# Cost after iteration 2768: 0.188608
# Cost after iteration 2769: 0.188766
# Cost after iteration 2770: 0.189291
# Cost after iteration 2771: 0.189584
# Cost after iteration 2772: 0.190574
# Cost after iteration 2773: 0.191120
# Cost after iteration 2774: 0.193079
# Cost after iteration 2775: 0.194131
# Cost after iteration 2776: 0.198212
# Cost after iteration 2777: 0.200196
# Cost after iteration 2778: 0.208854
# Cost after iteration 2779: 0.211193
# Cost after iteration 2780: 0.227720
# Cost after iteration 2781: 0.223410
# Cost after iteration 2782: 0.245766
# Cost after iteration 2783: 0.227509
# Cost after iteration 2784: 0.245082
# Cost after iteration 2785: 0.223871
# Cost after iteration 2786: 0.233833
# Cost after iteration 2787: 0.221260
# Cost after iteration 2788: 0.228765
# Cost after iteration 2789: 0.223037
# Cost after iteration 2790: 0.232359
# Cost after iteration 2791: 0.230458
# Cost after iteration 2792: 0.246248
# Cost after iteration 2793: 0.245129
# Cost after iteration 2794: 0.271872
# Cost after iteration 2795: 0.260743
# Cost after iteration 2796: 0.288814
# Cost after iteration 2797: 0.256506
# Cost after iteration 2798: 0.263564
# Cost after iteration 2799: 0.231527
# Cost after iteration 2800: 0.221658
# Cost after iteration 2801: 0.206346
# Cost after iteration 2802: 0.199506
# Cost after iteration 2803: 0.194675
# Cost after iteration 2804: 0.192777
# Cost after iteration 2805: 0.191450
# Cost after iteration 2806: 0.190871
# Cost after iteration 2807: 0.190366
# Cost after iteration 2808: 0.190093
# Cost after iteration 2809: 0.189831
# Cost after iteration 2810: 0.189658
# Cost after iteration 2811: 0.189491
# Cost after iteration 2812: 0.189363
# Cost after iteration 2813: 0.189240
# Cost after iteration 2814: 0.189137
# Cost after iteration 2815: 0.189037
# Cost after iteration 2816: 0.188948
# Cost after iteration 2817: 0.188862
# Cost after iteration 2818: 0.188783
# Cost after iteration 2819: 0.188706
# Cost after iteration 2820: 0.188635
# Cost after iteration 2821: 0.188565
# Cost after iteration 2822: 0.188499
# Cost after iteration 2823: 0.188435
# Cost after iteration 2824: 0.188374
# Cost after iteration 2825: 0.188315
# Cost after iteration 2826: 0.188258
# Cost after iteration 2827: 0.188203
# Cost after iteration 2828: 0.188151
# Cost after iteration 2829: 0.188099
# Cost after iteration 2830: 0.188051
# Cost after iteration 2831: 0.188003
# Cost after iteration 2832: 0.187958
# Cost after iteration 2833: 0.187913
# Cost after iteration 2834: 0.187872
# Cost after iteration 2835: 0.187831
# Cost after iteration 2836: 0.187794
# Cost after iteration 2837: 0.187757
# Cost after iteration 2838: 0.187725
# Cost after iteration 2839: 0.187694
# Cost after iteration 2840: 0.187668
# Cost after iteration 2841: 0.187644
# Cost after iteration 2842: 0.187629
# Cost after iteration 2843: 0.187615
# Cost after iteration 2844: 0.187617
# Cost after iteration 2845: 0.187621
# Cost after iteration 2846: 0.187654
# Cost after iteration 2847: 0.187688
# Cost after iteration 2848: 0.187781
# Cost after iteration 2849: 0.187872
# Cost after iteration 2850: 0.188089
# Cost after iteration 2851: 0.188290
# Cost after iteration 2852: 0.188779
# Cost after iteration 2853: 0.189203
# Cost after iteration 2854: 0.190328
# Cost after iteration 2855: 0.191243
# Cost after iteration 2856: 0.193976
# Cost after iteration 2857: 0.196059
# Cost after iteration 2858: 0.203080
# Cost after iteration 2859: 0.207443
# Cost after iteration 2860: 0.224974
# Cost after iteration 2861: 0.226045
# Cost after iteration 2862: 0.258800
# Cost after iteration 2863: 0.236259
# Cost after iteration 2864: 0.266160
# Cost after iteration 2865: 0.227093
# Cost after iteration 2866: 0.237944
# Cost after iteration 2867: 0.214450
# Cost after iteration 2868: 0.217337
# Cost after iteration 2869: 0.208078
# Cost after iteration 2870: 0.209147
# Cost after iteration 2871: 0.204634
# Cost after iteration 2872: 0.205310
# Cost after iteration 2873: 0.202929
# Cost after iteration 2874: 0.203710
# Cost after iteration 2875: 0.202287
# Cost after iteration 2876: 0.203209
# Cost after iteration 2877: 0.202058
# Cost after iteration 2878: 0.202937
# Cost after iteration 2879: 0.201701
# Cost after iteration 2880: 0.202324
# Cost after iteration 2881: 0.200890
# Cost after iteration 2882: 0.201118
# Cost after iteration 2883: 0.199535
# Cost after iteration 2884: 0.199357
# Cost after iteration 2885: 0.197771
# Cost after iteration 2886: 0.197303
# Cost after iteration 2887: 0.195870
# Cost after iteration 2888: 0.195286
# Cost after iteration 2889: 0.194105
# Cost after iteration 2890: 0.193545
# Cost after iteration 2891: 0.192637
# Cost after iteration 2892: 0.192174
# Cost after iteration 2893: 0.191504
# Cost after iteration 2894: 0.191153
# Cost after iteration 2895: 0.190670
# Cost after iteration 2896: 0.190419
# Cost after iteration 2897: 0.190072
# Cost after iteration 2898: 0.189902
# Cost after iteration 2899: 0.189652
# Cost after iteration 2900: 0.189547
# Cost after iteration 2901: 0.189367
# Cost after iteration 2902: 0.189317
# Cost after iteration 2903: 0.189189
# Cost after iteration 2904: 0.189189
# Cost after iteration 2905: 0.189103
# Cost after iteration 2906: 0.189157
# Cost after iteration 2907: 0.189110
# Cost after iteration 2908: 0.189229
# Cost after iteration 2909: 0.189223
# Cost after iteration 2910: 0.189431
# Cost after iteration 2911: 0.189474
# Cost after iteration 2912: 0.189816
# Cost after iteration 2913: 0.189927
# Cost after iteration 2914: 0.190487
# Cost after iteration 2915: 0.190698
# Cost after iteration 2916: 0.191632
# Cost after iteration 2917: 0.192006
# Cost after iteration 2918: 0.193619
# Cost after iteration 2919: 0.194274
# Cost after iteration 2920: 0.197179
# Cost after iteration 2921: 0.198307
# Cost after iteration 2922: 0.203707
# Cost after iteration 2923: 0.205334
# Cost after iteration 2924: 0.215137
# Cost after iteration 2925: 0.215549
# Cost after iteration 2926: 0.230879
# Cost after iteration 2927: 0.224681
# Cost after iteration 2928: 0.242182
# Cost after iteration 2929: 0.228429
# Cost after iteration 2930: 0.242963
# Cost after iteration 2931: 0.229704
# Cost after iteration 2932: 0.242060
# Cost after iteration 2933: 0.234002
# Cost after iteration 2934: 0.249025
# Cost after iteration 2935: 0.244539
# Cost after iteration 2936: 0.267762
# Cost after iteration 2937: 0.259484
# Cost after iteration 2938: 0.288622
# Cost after iteration 2939: 0.262586
# Cost after iteration 2940: 0.277562
# Cost after iteration 2941: 0.242514
# Cost after iteration 2942: 0.236208
# Cost after iteration 2943: 0.215177
# Cost after iteration 2944: 0.206106
# Cost after iteration 2945: 0.198080
# Cost after iteration 2946: 0.194854
# Cost after iteration 2947: 0.192520
# Cost after iteration 2948: 0.191570
# Cost after iteration 2949: 0.190784
# Cost after iteration 2950: 0.190397
# Cost after iteration 2951: 0.190048
# Cost after iteration 2952: 0.189835
# Cost after iteration 2953: 0.189639
# Cost after iteration 2954: 0.189496
# Cost after iteration 2955: 0.189362
# Cost after iteration 2956: 0.189252
# Cost after iteration 2957: 0.189147
# Cost after iteration 2958: 0.189055
# Cost after iteration 2959: 0.188966
# Cost after iteration 2960: 0.188884
# Cost after iteration 2961: 0.188806
# Cost after iteration 2962: 0.188732
# Cost after iteration 2963: 0.188661
# Cost after iteration 2964: 0.188593
# Cost after iteration 2965: 0.188527
# Cost after iteration 2966: 0.188464
# Cost after iteration 2967: 0.188402
# Cost after iteration 2968: 0.188344
# Cost after iteration 2969: 0.188286
# Cost after iteration 2970: 0.188231
# Cost after iteration 2971: 0.188178
# Cost after iteration 2972: 0.188126
# Cost after iteration 2973: 0.188076
# Cost after iteration 2974: 0.188027
# Cost after iteration 2975: 0.187979
# Cost after iteration 2976: 0.187934
# Cost after iteration 2977: 0.187889
# Cost after iteration 2978: 0.187846
# Cost after iteration 2979: 0.187804
# Cost after iteration 2980: 0.187764
# Cost after iteration 2981: 0.187724
# Cost after iteration 2982: 0.187687
# Cost after iteration 2983: 0.187650
# Cost after iteration 2984: 0.187615
# Cost after iteration 2985: 0.187582
# Cost after iteration 2986: 0.187550
# Cost after iteration 2987: 0.187521
# Cost after iteration 2988: 0.187494
# Cost after iteration 2989: 0.187469
# Cost after iteration 2990: 0.187450
# Cost after iteration 2991: 0.187432
# Cost after iteration 2992: 0.187425
# Cost after iteration 2993: 0.187420
# Cost after iteration 2994: 0.187434
# Cost after iteration 2995: 0.187453
# Cost after iteration 2996: 0.187510
# Cost after iteration 2997: 0.187574
# Cost after iteration 2998: 0.187722
# Cost after iteration 2999: 0.187876
# W1 = [[-1.91802898  1.73250171]
#  [-2.23963584  1.9719169 ]]
# b1 = [[ 4.83411869]
#  [-6.35915729]]
# W2 = [[ 7.25641736 -7.11372544]]
# b2 = [[-3.55693594]]

# %%
def predict(X, parameters):
    """
    Using the learned parameters, predicts a class for each example in X

    Arguments:
    parameters -- python dictionary containing your parameters
    X -- input data of size (n_x, m)

    Returns
    predictions -- vector of predictions of our model (blue: 0 / red: 1)
    """
    
    A2, cache = forward_propagation(X, parameters)
    predictions = A2 > 0.5

    return predictions

# %%
X_pred = np.array([[2, 8, 2, 8], [2, 8, 8, 2]])
Y_pred = predict(X_pred, parameters)

print(f"Coordinates (in the columns):\n{X_pred}")
print(f"Predictions:\n{Y_pred}")
# Out:
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]

# %%
def plot_decision_boundary(predict, parameters, X, Y):
    # Define bounds of the domain.
    min1, max1 = X[0, :].min() - 1, X[0, :].max() + 1
    min2, max2 = X[1, :].min() - 1, X[1, :].max() + 1
    # Define the x and y scale.
    x1grid = np.arange(min1, max1, 0.1)
    x2grid = np.arange(min2, max2, 0.1)
    # Create all of the lines and rows of the grid.
    xx, yy = np.meshgrid(x1grid, x2grid)
    # Flatten each grid to a vector.
    r1, r2 = xx.flatten(), yy.flatten()
    r1, r2 = r1.reshape((1, len(r1))), r2.reshape((1, len(r2)))
    # Vertical stack vectors to create x1,x2 input for the model.
    grid = np.vstack((r1, r2))
    # Make predictions for the grid.
    predictions = predict(grid, parameters)
    # Reshape the predictions back into a grid.
    zz = predictions.reshape(xx.shape)
    # Plot the grid of x, y and z values as a surface.
    plt.contourf(xx, yy, zz, cmap=plt.cm.Spectral.reversed())
    plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(["blue", "red"]))


# Plot the decision boundary.
plot_decision_boundary(predict, parameters, X, Y)
plt.title("Decision Boundary for hidden layer size " + str(n_h))
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 2')

# %%
n_samples = 2000
samples, labels = make_blobs(
    n_samples=n_samples,
    centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]),
    cluster_std=1.1,
    random_state=0,
)
labels[(labels == 0)] = 0
labels[(labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 1
X_2 = np.transpose(samples)
Y_2 = labels.reshape((1, n_samples))

plt.scatter(X_2[0, :], X_2[1, :], c=Y_2, cmap=colors.ListedColormap(["blue", "red"]))

# %%
# parameters_2 = nn_model(X_2, Y_2, n_h=1, num_iterations=3000, learning_rate=1.2, print_cost=False)
# parameters_2 = nn_model(X_2, Y_2, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=False)
parameters_2 = nn_model(
    X_2, Y_2, n_h=15, num_iterations=3000, learning_rate=1.2, print_cost=False
)

# This function will call predict function
plot_decision_boundary(predict, parameters_2, X_2, Y_2)
plt.title("Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Decision Boundary')
